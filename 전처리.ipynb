# %%
import pandas as pd

# %%
data = pd.read_excel('./1_danawn_crawling_result.xlsx')
data.info()
data.head()
#Null값은 비어있다는 값임(칸이 비어있다 정보가 없다) <-> non null은 정보가 있다는것
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   상품명     300 non-null    object
#  1   스펙 목록   300 non-null    object
#  2   가격      300 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 7.2+ KB
#                             상품명  \
# 0  LG전자 오브제컬렉션 코드제로 A9 AU9202WD
# 1    LG전자 오브제컬렉션 코드제로 A9S AX958
# 2       삼성전자 비스포크 제트 VS20B957D4
# 3                    샤오미 미홀 M22
# 4       삼성전자 비스포크 제트 VS20B956AX
#
#                                                스펙 목록       가격
# 0  핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 220W / [구성] 스테이션: 올인...   545810
# 1  핸디스틱청소기 / 무선 / 흡입+물걸레(동시) / 흡입력: 280W / [구성] 스...  1068200
# 2  핸디스틱청소기 / 무선 / 흡입+물걸레(교체) / 흡입력: 220W / [구성] 스...   609090
# 3  핸디스틱청소기 / 무선 / 흡입형 / [구성] 벽걸이거치 / 브러쉬: 바닥 / 물걸...   140490
# 4  핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 220W / [구성] 스테이션: 청정...   444787

# %%
#인기제품을 분류하기 위해 회사명을 없앰
company_list = []
product_list = []
for title in data['상품명']:
    title_info = title.split(' ', 1)
    if len(title_info) > 1:
        company_name = title_info[0]
        product_name = title_info[1]
    else:
        company_name = ""
        product_name = title_info[0]
    company_list.append(company_name)
    product_list.append(product_name)

# %%
print(company_list)
product_list
# Out:
# ['LG전자', 'LG전자', '삼성전자', '샤오미', '삼성전자', 'LG전자', '다이슨', 'LG전자', 'LG전자', 'LG전자', 'LG전자', 'LG전자', '삼성전자', '삼성전자', 'LG전자', '드리미', '샤크', 'LG전자', '삼성전자', '샤크', 'DIBEA', 'LG전자', '다이슨', 'LG전자', 'LG전자', '삼성전자', 'LG전자', '삼성전자', 'LG전자', 'LG전자', 'LG전자', 'LG전자', '삼성전자', '샤오미', '삼성전자', 'LG전자', '다이슨', 'LG전자', 'LG전자', 'LG전자', 'LG전자', 'LG전자', '삼성전자', '삼성전자', 'LG전자', '드리미', '샤크', 'LG전자', '삼성전자', '샤크', 'DIBEA', 'LG전자', '다이슨', 'LG전자', 'LG전자', '삼성전자', 'LG전자', '삼성전자', 'LG전자', 'LG전자', 'LG전자', 'LG전자', '삼성전자', '샤오미', '삼성전자', 'LG전자', '다이슨', 'LG전자', 'LG전자', 'LG전자', 'LG전자', 'LG전자', '삼성전자', '삼성전자', 'LG전자', '드리미', '샤크', 'LG전자', '삼성전자', '샤크', 'DIBEA', 'LG전자', '다이슨', 'LG전자', 'LG전자', '삼성전자', 'LG전자', '삼성전자', 'LG전자', 'LG전자', 'LG전자', 'LG전자', '삼성전자', '샤오미', '삼성전자', 'LG전자', '다이슨', 'LG전자', 'LG전자', 'LG전자', 'LG전자', 'LG전자', '삼성전자', '삼성전자', 'LG전자', '드리미', '샤크', 'LG전자', '삼성전자', '샤크', 'DIBEA', 'LG전자', '다이슨', 'LG전자', 'LG전자', '삼성전자', 'LG전자', '삼성전자', 'LG전자', 'LG전자', 'LG전자', 'LG전자', '삼성전자', '샤오미', '삼성전자', 'LG전자', '다이슨', 'LG전자', 'LG
# ...

# %%
#0번째에서만 가져온 스펙들
spec_list = data['스펙 목록'][0].split(' / ')
spec_list
# Out:
# ['핸디스틱청소기',
#  '무선',
#  '흡입형',
#  '흡입력: 220W',
#  '[구성] 스테이션: 올인원타워',
#  '먼지비움',
#  '충전',
#  '액서서리수납',
#  '스탠드거치',
#  '먼지비움시간: 60초',
#  '브러쉬: 바닥',
#  '물걸레: 별매',
#  '솔형',
#  '틈새',
#  '먼지봉투: 2.5L',
#  '[배터리] 사용시간: 1시간(최대)',
#  '분리형(1개)',
#  '리튬이온',
#  '[청소] 싸이클론흡입',
#  '스마트인버터모터',
#  '헤파필터',
#  '크기(가로x세로x깊이): 250x1120x260mm']

# %%
#사용시간이랑 흡입력 있는 애들만 모으기
for spec in spec_list:
    if '사용시간' in spec:
        use_time_spec = spec
    elif '흡입력' in spec:
        suction_spec = spec
print(use_time_spec)
print(suction_spec)
# Out:
# [배터리] 사용시간: 1시간(최대)
# 흡입력: 220W

# %%
#바로 위의 정보를 띄어쓰기 기준으로 없애고 각각 2번째랑 1번쨰꺼를 가져와서 정리함
use_time_value = use_time_spec.split(' ')[2].strip()
suction_value = suction_spec.split(' ')[1].strip()
print(use_time_value)
print(suction_value)
# Out:
# 1시간(최대)
# 220W

# %%
#맨위에 판타스틱 청소기 등등이 적혀있는 카테고리에 사용시간이랑 흡입력만 추출함 (+혼자서 할때는 리스트들 다따져가면서 해야함)
category_list = []
use_time_list = []
suction_list = []
for spec_data in data['스펙 목록']:
    spec_list = spec_data.split(' / ')
    #카테고리 추출
    category = spec_list[0]
    category_list.append(category)
    
    #사용시간, 흡입력 추출
    #사용시간이랑 흡입력 없는 애들은 none이라고 함
    use_time_value = None
    suction_value = None
    
    #배터리식이랑 다르게 충전식인 애들은 2번쨰거를 가져오지 못하므로 따로 둠
    for spec in spec_list:
        if '사용시간' in spec:
            if len(spec.split(' ')) > 2:
                use_time_value = spec.split(' ')[2].strip()
            else:
                use_time_value = spec.split(' ')[1].strip()
        if '흡입력' in spec:
            suction_value = spec.split(' ')[1].strip()
    use_time_list.append(use_time_value)
    suction_list.append(suction_value)

# %%
print("카테고리", len(category_list), category_list[0:10])
print("사용시간", len(use_time_list), use_time_list[0:10])
print("흡입력", len(suction_list), suction_list[0:10])
# Out:
# 카테고리 300 ['핸디스틱청소기', '핸디스틱청소기', '핸디스틱청소기', '핸디스틱청소기', '핸디스틱청소기', '핸디스틱청소기', '핸디스틱청소기', '핸디스틱청소기', '핸디스틱청소기', '핸디스틱청소기']
# 사용시간 300 ['1시간(최대)', '30분(최대)', '1시간(최대)', '50분(최대)', '1시간(최대)', '1시간(최대)', '1시간(최대)', '30분(최대)', '1시간(최대)', '30분(최대)']
# 흡입력 300 ['220W', '280W', '220W', None, '220W', '220W', '151AW', '320W', '210W', '250W']

# %%
#흡입시간부터 단위 통일시키고 함수화시킴
def convert_time_minute(time):
    try: #에러날것 같으니까 시도해줄래? (에러가 난것에 대한 조치는 expect)-코드 멈춤을 방지하기 위하여함
        if '시간' in time:
            hour = time.split('시간')[0]
            if '분' in time:
                minute = time.split('시간')[-1].split('분')[0]
            else:
                minute = 0
        else:
            hour = 0
            minute = time.split('분')[0]
        return int(hour)*60 + int(minute)
    except: #(에러가 난것에 대한 조치는 expect)
        return None

# %%
#검토?
times = ["40분", "4분", "1시간", "3시간 30분", "4시간"]
for time in times:
    time_value = convert_time_minute(time)
    print(time, "=", time_value)
# Out:
# 40분 = 40
# 4분 = 4
# 1시간 = 60
# 3시간 30분 = 210
# 4시간 = 240

# %%
#흡입력 단위 통일하기
def get_suction(value):
    try:
        value = value.upper()
        if "AW" in value or "W" in value:
            result = value.replace("A","").replace("W","")
            result = int(result.replace(",",""))
        elif "PA" in value:
            result = value.replace("PA","")
            result = int(result.replace(",",""))/100
        else:
            result = 0
        return result
    except:
        return 0

# %%
new_suction_list = []
for power in suction_list:
    value = get_suction(power)
    new_suction_list.append(value)

print(len(new_suction_list))
print(new_suction_list[0:10])
# Out:
# 300
# [220, 280, 220, 0, 220, 220, 151, 320, 210, 250]

# %%
new_use_time_list = []
for time in use_time_list:
    value = convert_time_minute(time)
    new_use_time_list.append(value)

print(len(new_use_time_list))
print(new_use_time_list[0:10])
# Out:
# 300
# [60, 30, 60, 50, 60, 60, 60, 30, 60, 30]

# %%
#전처리 데이터 정리
pd_data = pd.DataFrame()
pd_data['카테고리'] = category_list
pd_data['회사명'] = company_list
pd_data['제품'] = product_list
pd_data['가격'] = data['가격']
pd_data['사용시간'] = new_use_time_list
pd_data['흡입력'] = new_suction_list
pd_data.head()
# Out:
#       카테고리   회사명                       제품       가격  사용시간    흡입력
# 0  핸디스틱청소기  LG전자  오브제컬렉션 코드제로 A9 AU9202WD   545810    60  220.0
# 1  핸디스틱청소기  LG전자    오브제컬렉션 코드제로 A9S AX958  1068200    30  280.0
# 2  핸디스틱청소기  삼성전자       비스포크 제트 VS20B957D4   609090    60  220.0
# 3  핸디스틱청소기   샤오미                   미홀 M22   140490    50    0.0
# 4  핸디스틱청소기  삼성전자       비스포크 제트 VS20B956AX   444787    60  220.0

# %%
# 엑셀로 저장
pd_data_final = pd_data[pd_data['카테고리'].isin(['핸디스틱청소기'])]
pd_data_final.to_excel('./2_danawa_data_final.xlsx', index = False)
