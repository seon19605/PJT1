# %%
import pandas as pd
danawa_data = pd.read_excel('./2_danawa_data_final.xlsx')
danawa_data.head()
#핸드스틱 청소기로 카테고리 제한
#현재 인기순 정렬
# Out:
#       카테고리   회사명                       제품       가격  사용시간  흡입력
# 0  핸디스틱청소기  LG전자  오브제컬렉션 코드제로 A9 AU9202WD   545810    60  220
# 1  핸디스틱청소기  LG전자    오브제컬렉션 코드제로 A9S AX958  1068200    30  280
# 2  핸디스틱청소기  삼성전자       비스포크 제트 VS20B957D4   609090    60  220
# 3  핸디스틱청소기   샤오미                   미홀 M22   140490    50    0
# 4  핸디스틱청소기  삼성전자       비스포크 제트 VS20B956AX   444787    60  220

# %%
#흡입 기준 정렬
top_list = danawa_data.sort_values(["흡입력"], ascending = True)
#거짓은 내림차순 참은 오름차순
top_list.head()
# Out:
#         카테고리  회사명                         제품      가격  사용시간  흡입력
# 46   핸디스틱청소기   샤크  에보 파워 시스템 NEO 플러스 LC351KR  792410    35    0
# 33   핸디스틱청소기  샤오미                     미홀 M22  140490    50    0
# 153  핸디스틱청소기  샤오미                     미홀 M22  140490    50    0
# 243  핸디스틱청소기  샤오미                     미홀 M22  140490    50    0
# 183  핸디스틱청소기  샤오미                     미홀 M22  140490    50    0

# %%
# 사용시간 기준 정렬
top_list = danawa_data.sort_values(["사용시간"], ascending = False)
top_list.head()
# Out:
#         카테고리  회사명   제품      가격  사용시간  흡입력
# 195  핸디스틱청소기  드리미  V11  179945    90  250
# 165  핸디스틱청소기  드리미  V11  179945    90  250
# 15   핸디스틱청소기  드리미  V11  179945    90  250
# 255  핸디스틱청소기  드리미  V11  179945    90  250
# 105  핸디스틱청소기  드리미  V11  179945    90  250

# %%
#사용시간과 흡입력 기준 정렬
top_list = danawa_data.sort_values(["사용시간", "흡입력"], ascending = False)
top_list.head()
# Out:
#         카테고리  회사명   제품      가격  사용시간  흡입력
# 15   핸디스틱청소기  드리미  V11  179945    90  250
# 45   핸디스틱청소기  드리미  V11  179945    90  250
# 75   핸디스틱청소기  드리미  V11  179945    90  250
# 105  핸디스틱청소기  드리미  V11  179945    90  250
# 135  핸디스틱청소기  드리미  V11  179945    90  250

# %%
#평균값 구하기
price_mean_value = danawa_data['가격'].mean()
suction_mean_value = danawa_data['흡입력'].mean()
use_time_mean_value = danawa_data['사용시간'].mean()
print('가격 평균', price_mean_value)
print('흡입력 평균', suction_mean_value)
print('사용시간 평균', use_time_mean_value)
# Out:
# 가격 평균 668696.0666666667
# 흡입력 평균 212.7
# 사용시간 평균 50.733333333333334

# %%
condition_data = danawa_data[
    (danawa_data['가격'] <= price_mean_value) &
    (danawa_data['흡입력'] >= suction_mean_value) &
    (danawa_data['사용시간'] >= use_time_mean_value)]
condition_data
# Out:
#         카테고리   회사명                       제품      가격  사용시간  흡입력
# 0    핸디스틱청소기  LG전자  오브제컬렉션 코드제로 A9 AU9202WD  545810    60  220
# 2    핸디스틱청소기  삼성전자       비스포크 제트 VS20B957D4  609090    60  220
# 4    핸디스틱청소기  삼성전자       비스포크 제트 VS20B956AX  444787    60  220
# 5    핸디스틱청소기  LG전자  오브제컬렉션 코드제로 A9 AU9272WD  633840    60  220
# 12   핸디스틱청소기  삼성전자       비스포크 제트 VS20B956D5  546970    60  220
# ..       ...   ...                      ...     ...   ...  ...
# 282  핸디스틱청소기  삼성전자       비스포크 제트 VS20B956D5  546970    60  220
# 283  핸디스틱청소기  삼성전자      비스포크 제트 VS20B956BUE  448840    60  220
# 285  핸디스틱청소기   드리미                      V11  179945    90  250
# 296  핸디스틱청소기  LG전자  오브제컬렉션 코드제로 A9 AU9402WD  634640    60  220
# 299  핸디스틱청소기  LG전자  오브제컬렉션 코드제로 A9 AS9272WD  557670    60  220
#
# [90 rows x 6 columns]

# %%
from matplotlib import font_manager, rc
import matplotlib.pyplot as plt
import seaborn as sns
import platform

# %%
#영어를 한글로 바꿈
font_path = ''
if platform.system() == 'Windows': 
    font_path = 'c:/Windows/Fonts/malgun.ttf'
    font_name = font_manager.FontProperties(fname = font_path).get_name()
    rc('font', family = font_name)
elif platform.system() == 'Darwin':
    font_path = '/Users/$USER/Library/Fonts/AppleGothic.ttf'
    rc('font', family = 'AppleGothic')
else: 
    print('Check your OS system')
    
# %matplotlib inline #그래프를 그려주는 프로그램 표를 실행하고 그 아래에 그래프를 그려줌
# Out:
# UsageError: unrecognized arguments: #그래프를 그려주는 프로그램 표를 실행하고 그 아래에 그래프를 그려줌

# %%
#결치값(정확하게 있지 않은 값 우리가 원하지 않는 값 데이터가 없는애들)을 없애줌
chart_data = danawa_data.dropna(axis = 0)
len(chart_data)

# %%
suction_max_value = chart_data['흡입력'].max()
suction_min_value = chart_data['흡입력'].min()
use_time_max_value = chart_data['사용시간'].max()
use_time_min_value = chart_data['사용시간'].min()
print(suction_max_value)
print(suction_min_value)

# %%
#피규어를 그림
#scatterplot는 더 색깔이 다양한 그래프
plt.figure(figsize= (20,10))
plt.title("무선 핸디스틱청소기 차트")
sns.scatterplot(x = '흡입력', y = '사용시간', size = '가격', hue=chart_data['회사명'],
                data=chart_data, sizes=(10, 1000), legend=False)
#가격이 비싸면 동그라미 크게 됨
plt.plot([0, suction_max_value], [use_time_mean_value, use_time_mean_value],
         'r--', lw=1)
plt.plot([suction_mean_value, suction_mean_value], [use_time_min_value, use_time_max_value],
         'r--', lw=1)
plt.show()
#x축 지정함
#빨간색 점선이 평균값
#로 흡입력이 크면 사용시간도 크다

# %%
chart_data_selected = chart_data[:25]
len(chart_data_selected)

# %%
suction_max_value = chart_data_selected['흡입력'].max()
suction_mean_value = chart_data_selected['흡입력'].mean()
use_time_max_value = chart_data_selected['사용시간'].max()
use_time_mean_value = chart_data['사용시간'].mean()
plt.figure(figsize=(20,10))
plt.title("무선 핸드스틱청소기 Top 20")
sns.scatterplot(x = '흡입력', y = '사용시간',
                size = '가격', hue=chart_data_selected['회사명'],
                data=chart_data_selected, sizes=(100, 2000),
                legend=False)
plt.plot([0, suction_max_value], [use_time_mean_value, use_time_mean_value],
         'r--', lw=1)
plt.plot([suction_mean_value, suction_mean_value], [0, use_time_max_value],
         'r--', lw=1)
#동그라미 그리고 텍스트 붙여라
dict_xy = dict()
for index,row in chart_data_selected.iterrows():
    x = row['흡입력']
    y = row['사용시간']
    s = row['제품']
    #s = row['제품'].split(" ")[0]
    try:
        dict_xy[(x, y)] += 1
    except:
        dict_xy[(x, y)] = 1
    plt.text(x, y+3*dict_xy[(x, y)], s, size=12)

#plt.show()
plt.savefig('top20.png')
